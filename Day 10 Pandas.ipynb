# %%
import pandas as pd

# %% [markdown]
# # 4 Principle of the keep_deffault_na

# %% [raw]
# 1. If `keep_default_na` is True, and `na_values` are specified, `na_values`is appended to the default NaN values used for parsing.

# %%
na_values=df1=pd.read_csv ('C:\\Users\\pc\\Downloads\\data_#na.csv',keep_default_na=True,
                           na_values=["NULL","#NA"])
na_values
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0    NaN
# 1   Aadhya    NaN     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0    NaN
# 4   Parshv   90.0     AC
# 5   Mittal    NaN     BA
# 6  Archana   82.0     BB

# %% [raw]
# 2.If `keep_default_na` is True, and `na_values` are not specified, only
#  the default NaN values are used for parsing.

# %%
na_values=df1=pd.read_csv ('C:\\Users\\pc\\Downloads\\data_#na.csv',keep_default_na=True)
na_values
# it will not convert the string into NAN e.g Not available , wrong data
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0    NaN
# 1   Aadhya    NaN     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0    NaN
# 4   Parshv   90.0     AC
# 5   Mittal    NaN     BA
# 6  Archana   82.0     BB

# %% [raw]
# 3.If `keep_default_na` is False, and `na_values` are specified, only
# the NaN values specified `na_values` are used for parsing. it just convert the specifeid values

# %%
na_values=df1=pd.read_csv ('C:\\Users\\pc\\Downloads\\data_#na.csv',keep_default_na=False,
                           na_values=["NULL"])
na_values
# Out:
#       Name Marks Grades
# 0  Priyang    98    NaN
# 1   Aadhya   #NA     AB
# 2   Krisha    99     AA
# 3   Vedant    87     NA
# 4   Parshv    90     AC
# 5   Mittal   #NA     BA
# 6  Archana    82     BB

# %% [raw]
# 4.If `keep_default_na` is False, and `na_values` are not specified, no
# strings will be parsed as NaN.

# %%
na_values=df1=pd.read_csv ('C:\\Users\\pc\\Downloads\\data_#na.csv',keep_default_na=False)
na_values
# Out:
#       Name Marks Grades
# 0  Priyang    98   NULL
# 1   Aadhya   #NA     AB
# 2   Krisha    99     AA
# 3   Vedant    87     NA
# 4   Parshv    90     AC
# 5   Mittal   #NA     BA
# 6  Archana    82     BB

# %% [raw]
# Note that if `na_filter` is passed in as False, the `keep_default_na` and
# `na_values` parameters will be ignored.We have to sure that there is no NAN and NA values are in our
# dataFram

# %%
# if we make the na_filter false then it stop the background parcing
data=pd.read_csv ('C:\\Users\\pc\\iris.csv',na_filter=False)
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
na_values=df1=pd.read_csv ('C:\\Users\\pc\\Downloads\\data_#na.csv',na_filter=False)
na_values
# Out:
#       Name Marks Grades
# 0  Priyang    98   NULL
# 1   Aadhya   #NA     AB
# 2   Krisha    99     AA
# 3   Vedant    87     NA
# 4   Parshv    90     AC
# 5   Mittal   #NA     BA
# 6  Archana    82     BB

# %% [markdown]
# # Drop the missing values

# %%
data=pd.read_csv('C:\\Users\\pc\\Downloads\\data_m.csv')

# %%
data.dropna(axis=0,how='any')
# Out:
#       Name  Marks Grades
# 2   Krisha   99.0     AA
# 4   Parshv   90.0     AC
# 6  Archana   82.0     BB

# %%
data.dropna(axis=1,how='any')
# Out:
#       Name
# 0  Priyang
# 1   Aadhya
# 2   Krisha
# 3   Vedant
# 4   Parshv
# 5   Mittal
# 6  Archana

# %%
data.dropna(axis=0,how='all')
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0    NaN
# 1   Aadhya    NaN     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0    NaN
# 4   Parshv   90.0     AC
# 5   Mittal    NaN     BA
# 6  Archana   82.0     BB

# %%
# drop  the col having all missing value
data.dropna(axis=1,how='all')
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0    NaN
# 1   Aadhya    NaN     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0    NaN
# 4   Parshv   90.0     AC
# 5   Mittal    NaN     BA
# 6  Archana   82.0     BB

# %%
# keep only the row having 2 non NA_values
data.dropna(axis=0,thresh=2)
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0    NaN
# 1   Aadhya    NaN     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0    NaN
# 4   Parshv   90.0     AC
# 5   Mittal    NaN     BA
# 6  Archana   82.0     BB

# %%
# define in which col is missing value
data.dropna(subset=["Marks"])

# %%
df1=data.dropna(inplace=False)
# it will create the copy of the original with performed parameters
# Out:
#       Name  Marks Grades
# 2   Krisha   99.0     AA
# 4   Parshv   90.0     AC
# 6  Archana   82.0     BB

# %% [markdown]
# # FIll Missing values

# %%
# fill all NAN values with 0s all the missing values are replaced with 0
data.fillna(0)
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0      0
# 1   Aadhya    0.0     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0      0
# 4   Parshv   90.0     AC
# 5   Mittal    0.0     BA
# 6  Archana   82.0     BB
