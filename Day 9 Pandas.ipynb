# %%
import pandas as pd

# %% [markdown]
# # Header Method

# %%
data=pd.read_csv ('C:\\Users\\pc\\iris.csv',
                 header=1)
data
# Out:
#        1  5.1  3.5  1.4  0.2     Iris-setosa
# 0      2  4.9  3.0  1.4  0.2     Iris-setosa
# 1      3  4.7  3.2  1.3  0.2     Iris-setosa
# 2      4  4.6  3.1  1.5  0.2     Iris-setosa
# 3      5  5.0  3.6  1.4  0.2     Iris-setosa
# 4      6  5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...  ...             ...
# 144  146  6.7  3.0  5.2  2.3  Iris-virginica
# 145  147  6.3  2.5  5.0  1.9  Iris-virginica
# 146  148  6.5  3.0  5.2  2.0  Iris-virginica
# 147  149  6.2  3.4  5.4  2.3  Iris-virginica
# 148  150  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 6 columns]

# %%
data=pd.read_csv ('C:\\Users\\pc\\iris.csv',
                 header=None)
data
# if header is none then header is taken as indexes
# Out:
#        0              1             2              3             4  \
# 0     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 1      1            5.1           3.5            1.4           0.2
# 2      2            4.9           3.0            1.4           0.2
# 3      3            4.7           3.2            1.3           0.2
# 4      4            4.6           3.1            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 146  146            6.7           3.0            5.2           2.3
# 147  147            6.3           2.5            5.0           1.9
# 148  148            6.5           3.0            5.2           2.0
# 149  149            6.2           3.4            5.4           2.3
# 150  150            5.9           3.0            5.1           1.8
#
#                   5
# 0           Species
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# names parameter is used for header names
data=pd.read_csv ('C:\\Users\\pc\\iris.csv',
                 names=['USAMA','HAIDER','ALI','FAHAD','AKHTAR','ZAIN'])
data
# Out:
#     USAMA         HAIDER           ALI          FAHAD        AKHTAR  \
# 0      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 1       1            5.1           3.5            1.4           0.2
# 2       2            4.9           3.0            1.4           0.2
# 3       3            4.7           3.2            1.3           0.2
# 4       4            4.6           3.1            1.5           0.2
# ..    ...            ...           ...            ...           ...
# 146   146            6.7           3.0            5.2           2.3
# 147   147            6.3           2.5            5.0           1.9
# 148   148            6.5           3.0            5.2           2.0
# 149   149            6.2           3.4            5.4           2.3
# 150   150            5.9           3.0            5.1           1.8
#
#                ZAIN
# 0           Species
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data=pd.read_csv ('C:\\Users\\pc\\iris.csv',
                 header=None
                 )
data
# Out:
#        0              1             2              3             4  \
# 0     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 1      1            5.1           3.5            1.4           0.2
# 2      2            4.9           3.0            1.4           0.2
# 3      3            4.7           3.2            1.3           0.2
# 4      4            4.6           3.1            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 146  146            6.7           3.0            5.2           2.3
# 147  147            6.3           2.5            5.0           1.9
# 148  148            6.5           3.0            5.2           2.0
# 149  149            6.2           3.4            5.4           2.3
# 150  150            5.9           3.0            5.1           1.8
#
#                   5
# 0           Species
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data=pd.read_csv ('C:\\Users\\pc\\iris.csv', dtype={'Id':'float32'})
data
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1.0            5.1           3.5            1.4           0.2
# 1      2.0            4.9           3.0            1.4           0.2
# 2      3.0            4.7           3.2            1.3           0.2
# 3      4.0            4.6           3.1            1.5           0.2
# 4      5.0            5.0           3.6            1.4           0.2
# ..     ...            ...           ...            ...           ...
# 145  146.0            6.7           3.0            5.2           2.3
# 146  147.0            6.3           2.5            5.0           1.9
# 147  148.0            6.5           3.0            5.2           2.0
# 148  149.0            6.2           3.4            5.4           2.3
# 149  150.0            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
data.squeeze=True

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Chunk Method

# %%
data=pd.read_csv ('C:\\Users\\pc\\iris.csv',chunksize=10)
for chunk in data:
    print(chunk)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# ...

# %%
df=pd.read_csv ('C:\\Users\\pc\\iris.csv')
# by giving axis is 1 it means drop the firdt col
df1=df.drop('Id',axis=1,inplace=True)
df1
# this return nothing bcz inplace is true

# %%
df
# now id col is permanentaly remove from the original dataset bcz inplace is true
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Null Values

# %%
df.isnull().sum(axis=0)
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 750

# %%
# we can perform thie method on a series
df['SepalLengthCm'].isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # na_values

# %%
df1=pd.read_csv ('C:\\Users\\pc\\Downloads\\data_m1.csv',na_values=['not available'])
df1
# not availabel is converted to NAN and if we want to pass multiple values to na_values 
# then pass a python list to it.
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0    NaN
# 1   Aadhya    NaN     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0    NaN
# 4   Parshv   90.0     AC
# 5   Mittal    NaN     BA
# 6  Archana   82.0     BB

# %%
# keep_default_na will give the actual formatas NA NULL not as NAN
na_values=df1=pd.read_csv ('C:\\Users\\pc\\Downloads\\data_#na.csv',keep_default_na=False)
na_values
# Out:
#       Name Marks Grades
# 0  Priyang    98   NULL
# 1   Aadhya   #NA     AB
# 2   Krisha    99     AA
# 3   Vedant    87     NA
# 4   Parshv    90     AC
# 5   Mittal   #NA     BA
# 6  Archana    82     BB
